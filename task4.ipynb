# %%
import pandas as pd

# %%
df = pd.read_csv(r'sales_data.csv')

# %%
df
# Out:
#     OrderID        Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0      1001  2024-09-07  North       Salma   Headset      8         60    480
# 1      1002  2024-08-23   East      Mariam  Keyboard      7         40    280
# 2      1003  2024-05-04  North     Youssef   Monitor      8        150   1200
# 3      1004  2024-12-08  North        Nada   Headset      2         60    120
# 4      1005  2024-09-12  South        Nada     Mouse      5         25    125
# ..      ...         ...    ...         ...       ...    ...        ...    ...
# 95     1096  2024-11-27   West      Mariam    Laptop      2        850   1700
# 96     1097  2024-09-04   West        Nada    Laptop      8        850   6800
# 97     1098  2024-08-03   East       Ahmed   Headset      7         60    420
# 98     1099  2024-07-17  North     Youssef   Headset      7         60    420
# 99     1100  2024-08-22  South      Mariam  Keyboard      5         40    200
#
#    CustomerType
# ...

# %% [markdown]
# ### Level 1

# %%
df.head()
# Out:
#    OrderID        Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0     1001  2024-09-07  North       Salma   Headset      8         60    480
# 1     1002  2024-08-23   East      Mariam  Keyboard      7         40    280
# 2     1003  2024-05-04  North     Youssef   Monitor      8        150   1200
# 3     1004  2024-12-08  North        Nada   Headset      2         60    120
# 4     1005  2024-09-12  South        Nada     Mouse      5         25    125
#
#   CustomerType
# 0    Corporate
# 1    Corporate
# 2     Consumer
# 3     Consumer
# 4    Corporate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       100 non-null    int64
#  1   Date          100 non-null    object
#  2   Region        100 non-null    object
#  3   Salesperson   100 non-null    object
#  4   Product       100 non-null    object
#  5   Units         100 non-null    int64
#  6   UnitPrice     100 non-null    int64
#  7   Total         100 non-null    int64
#  8   CustomerType  100 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
len(df)
# Out:
# 100

# %%
df.Region.unique()
# Out:
# array(['North', 'East', 'South', 'West'], dtype=object)

# %%
df.CustomerType.unique()
# Out:
# array(['Corporate', 'Consumer'], dtype=object)

# %%
print(df.Total.min(),df.Total.max(),df.Total.mean())
# Out:
# 25 7650 1458.3

# %% [markdown]
# ### Level 2

# %%
df.query("Salesperson == 'Ahmed'")
# Out:
#     OrderID        Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 9      1010  2024-06-03  South       Ahmed   Monitor      2        150    300
# 20     1021  2024-04-16   East       Ahmed   Monitor      8        150   1200
# 30     1031  2024-04-04  South       Ahmed   Monitor      4        150    600
# 39     1040  2024-10-26   East       Ahmed  Keyboard     10         40    400
# 41     1042  2024-02-07   West       Ahmed     Mouse      4         25    100
# 43     1044  2024-03-30   East       Ahmed  Keyboard      1         40     40
# 49     1050  2024-05-04  North       Ahmed    Laptop      6        850   5100
# 59     1060  2024-12-25  South       Ahmed   Monitor      1        150    150
# 61     1062  2024-05-28   West       Ahmed  Keyboard      9         40    360
# 64     1065  2024-06-12  South       Ahmed   Headset      4         60    240
# 69     1070  2024-09-05   West       Ahmed   Monitor      1        150    150
# ...

# %%
df[df['Units']>5]
# Out:
#     OrderID        Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0      1001  2024-09-07  North       Salma   Headset      8         60    480
# 1      1002  2024-08-23   East      Mariam  Keyboard      7         40    280
# 2      1003  2024-05-04  North     Youssef   Monitor      8        150   1200
# 5      1006  2024-09-25  South      Mariam   Headset      9         60    540
# 8      1009  2024-01-26  North     Youssef    Laptop      7        850   5950
# 11     1012  2024-06-28  South       Salma   Monitor      8        150   1200
# 13     1014  2024-01-25  South       Salma     Mouse      6         25    150
# 16     1017  2024-10-20  North        Nada   Monitor      9        150   1350
# 18     1019  2024-12-20   East      Mariam    Laptop      9        850   7650
# 19     1020  2024-06-05  North     Youssef    Laptop      9        850   7650
# 20     1021  2024-04-16   East       Ahmed   Monitor      8        150   1200
# ...

# %%
df.sort_values('Total',ascending = False)
# Out:
#     OrderID        Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 18     1019  2024-12-20   East      Mariam    Laptop      9        850   7650
# 19     1020  2024-06-05  North     Youssef    Laptop      9        850   7650
# 53     1054  2024-06-07  South      Mariam    Laptop      9        850   7650
# 57     1058  2024-06-03  South        Omar    Laptop      9        850   7650
# 78     1079  2024-05-25   West       Ahmed    Laptop      9        850   7650
# ..      ...         ...    ...         ...       ...    ...        ...    ...
# 27     1028  2024-11-03  North     Youssef  Keyboard      1         40     40
# 43     1044  2024-03-30   East       Ahmed  Keyboard      1         40     40
# 42     1043  2024-12-02   West      Mariam  Keyboard      1         40     40
# 91     1092  2024-01-23   West        Nada  Keyboard      1         40     40
# 24     1025  2024-08-24  South       Salma     Mouse      1         25     25
#
#    CustomerType
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[df['Date'].dt.month== 1]
# Out:
#     OrderID       Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 8      1009 2024-01-26  North     Youssef    Laptop      7        850   5950
# 13     1014 2024-01-25  South       Salma     Mouse      6         25    150
# 34     1035 2024-01-22   West       Salma   Monitor      4        150    600
# 35     1036 2024-01-04   West        Omar     Mouse      7         25    175
# 80     1081 2024-01-27  North      Mariam    Laptop      8        850   6800
# 89     1090 2024-01-03  South        Nada   Headset      4         60    240
# 91     1092 2024-01-23   West        Nada  Keyboard      1         40     40
#
#    CustomerType
# 8      Consumer
# 13     Consumer
# 34     Consumer
# 35     Consumer
# 80    Corporate
# 89     Consumer
# 91     Consumer

# %%
df.query("CustomerType == 'Corporate' and Total > 1000")
# Out:
#     OrderID       Date Region Salesperson  Product  Units  UnitPrice  Total  \
# 7      1008 2024-06-01  North       Salma   Laptop      3        850   2550
# 11     1012 2024-06-28  South       Salma  Monitor      8        150   1200
# 18     1019 2024-12-20   East      Mariam   Laptop      9        850   7650
# 19     1020 2024-06-05  North     Youssef   Laptop      9        850   7650
# 23     1024 2024-03-24  North      Mariam   Laptop      7        850   5950
# 37     1038 2024-09-13  North        Nada   Laptop      4        850   3400
# 40     1041 2024-08-25  South        Omar   Laptop      4        850   3400
# 46     1047 2024-08-23   West        Nada  Monitor      7        150   1050
# 53     1054 2024-06-07  South      Mariam   Laptop      9        850   7650
# 56     1057 2024-04-21   East      Mariam   Laptop      5        850   4250
# 57     1058 2024-06-03  South        Omar   Laptop      9        850   7650
# ...

# %% [markdown]
# ### level 3

# %%
df
# Out:
#     OrderID       Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0      1001 2024-09-07  North       Salma   Headset      8         60    480
# 1      1002 2024-08-23   East      Mariam  Keyboard      7         40    280
# 2      1003 2024-05-04  North     Youssef   Monitor      8        150   1200
# 3      1004 2024-12-08  North        Nada   Headset      2         60    120
# 4      1005 2024-09-12  South        Nada     Mouse      5         25    125
# ..      ...        ...    ...         ...       ...    ...        ...    ...
# 95     1096 2024-11-27   West      Mariam    Laptop      2        850   1700
# 96     1097 2024-09-04   West        Nada    Laptop      8        850   6800
# 97     1098 2024-08-03   East       Ahmed   Headset      7         60    420
# 98     1099 2024-07-17  North     Youssef   Headset      7         60    420
# 99     1100 2024-08-22  South      Mariam  Keyboard      5         40    200
#
#    CustomerType  Month  DiscountedTotal
# ...

# %%
df.groupby('Region')['Total'].sum()
# Out:
# Region
# East     16960
# North    62255
# South    42180
# West     24435
# Name: Total, dtype: int64

# %%
df.groupby('Salesperson')['Total'].mean()
# Out:
# Salesperson
# Ahmed      1245.555556
# Mariam     2526.176471
# Nada       1013.478261
# Omar       1542.352941
# Salma       829.615385
# Youssef    1679.166667
# Name: Total, dtype: float64

# %%
df['CustomerType'].value_counts()
# Out:
# CustomerType
# Consumer     56
# Corporate    44
# Name: count, dtype: int64

# %%
df.groupby('Product')['Total'].sum().idxmax()
# Out:
# 'Laptop'

# %%
s1 = df.groupby('Salesperson')['Units'].sum()
s1[s1==s1.max()]
# Out:
# Salesperson
# Nada    103
# Name: Units, dtype: int64

# %% [markdown]
# ### Level 4

# %%
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#     OrderID       Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0      1001 2024-09-07  North       Salma   Headset      8         60    480
# 1      1002 2024-08-23   East      Mariam  Keyboard      7         40    280
# 2      1003 2024-05-04  North     Youssef   Monitor      8        150   1200
# 3      1004 2024-12-08  North        Nada   Headset      2         60    120
# 4      1005 2024-09-12  South        Nada     Mouse      5         25    125
# ..      ...        ...    ...         ...       ...    ...        ...    ...
# 95     1096 2024-11-27   West      Mariam    Laptop      2        850   1700
# 96     1097 2024-09-04   West        Nada    Laptop      8        850   6800
# 97     1098 2024-08-03   East       Ahmed   Headset      7         60    420
# 98     1099 2024-07-17  North     Youssef   Headset      7         60    420
# 99     1100 2024-08-22  South      Mariam  Keyboard      5         40    200
#
#    CustomerType  Month
# ...

# %%
df.groupby('Month')['Total'].sum()
# Out:
# Month
# 1     13955
# 2      5680
# 3      6750
# 4     11120
# 5     19945
# 6     27420
# 7      6790
# 8     11350
# 9     15285
# 10     2780
# 11     2405
# 12    22350
# Name: Total, dtype: int64

# %%
s1 = df.groupby('Month')['Total'].sum()
s1[s1==s1.max()]
# Out:
# Month
# 6    27420
# Name: Total, dtype: int64

# %%
df.groupby('Month')['Total'].mean()
# Out:
# Month
# 1     1993.571429
# 2      946.666667
# 3     1125.000000
# 4     1390.000000
# 5     2493.125000
# 6     3427.500000
# 7      970.000000
# 8      810.714286
# 9     1389.545455
# 10     463.333333
# 11     601.250000
# 12    1490.000000
# Name: Total, dtype: float64

# %%
df.groupby(['Region', 'Month'])['Total'].sum()
# Out:
# Region  Month
# East    2          120
#         3          200
#         4         5900
#         5          850
#         7          600
#         8          880
#         10         400
#         12        8010
# North   1        12750
#         2         1210
#         3         6350
#         4         4250
#         5        10550
#         6        10380
#         7         2220
#         8           75
#         9         7330
#         10        2380
#         11          40
#         12        4720
# South   1          390
#         2         4250
#         4          600
#         6        17040
#         7         3970
#         8         9235
#         9          845
#         12        5850
# West    1          815
#         2          100
#         3          200
#         4          370
#         5         8545
#         8         1160
#         9         7110
#         11        2365
#         12        3770
# Name: Total, dtype: int64

# %% [markdown]
# ### level 5

# %%
top3_products = df.groupby('Product')['Total'].sum().sort_values(ascending=False).head(3)
print("Top 3 products by revenue:")
print(top3_products)
# Out:
# Top 3 products by revenue:
# Product
# Laptop     121550
# Monitor     13800
# Headset      4620
# Name: Total, dtype: int64

# %%
salesperson_contribution = (df.groupby('Salesperson')['Total'].sum() / df['Total'].sum()) * 100
print("\nSalesperson contribution (% of total revenue):")
print(salesperson_contribution)
# Out:
# Salesperson contribution (% of total revenue):
# Salesperson
# Ahmed      15.374066
# Mariam     29.448673
# Nada       15.984365
# Omar       17.979840
# Salma       7.395598
# Youssef    13.817459
# Name: Total, dtype: float64

# %%
df['DiscountedTotal'] = df['Total'] * 0.95
print("\nNew column 'DiscountedTotal' added.")
df
# Out:
# New column 'DiscountedTotal' added.
#     OrderID       Date Region Salesperson   Product  Units  UnitPrice  Total  \
# 0      1001 2024-09-07  North       Salma   Headset      8         60    480
# 1      1002 2024-08-23   East      Mariam  Keyboard      7         40    280
# 2      1003 2024-05-04  North     Youssef   Monitor      8        150   1200
# 3      1004 2024-12-08  North        Nada   Headset      2         60    120
# 4      1005 2024-09-12  South        Nada     Mouse      5         25    125
# ..      ...        ...    ...         ...       ...    ...        ...    ...
# 95     1096 2024-11-27   West      Mariam    Laptop      2        850   1700
# 96     1097 2024-09-04   West        Nada    Laptop      8        850   6800
# 97     1098 2024-08-03   East       Ahmed   Headset      7         60    420
# 98     1099 2024-07-17  North     Youssef   Headset      7         60    420
# 99     1100 2024-08-22  South      Mariam  Keyboard      5         40    200
#
# ...

# %%
most_sold_per_region = df.groupby(['Region', 'Product'])['Units'].sum().reset_index()
most_sold_per_region = most_sold_per_region.loc[most_sold_per_region.groupby('Region')['Units'].idxmax()]
print("\nMost sold product per region:")
print(most_sold_per_region)
# Out:
# Most sold product per region:
#    Region   Product  Units
# 1    East  Keyboard     31
# 7   North    Laptop     63
# 12  South    Laptop     42
# 19   West     Mouse     41

# %%
import matplotlib.pyplot as plt

# %%
daily_avg_revenue = df.groupby('Date')['Total'].mean()
plt.figure(figsize=(10,5))
plt.plot(daily_avg_revenue.index, daily_avg_revenue.values, marker='o')
plt.title('Daily Average Revenue Trend')
plt.xlabel('Date')
plt.ylabel('Average Revenue')
plt.grid(True)
plt.show()
